# %% [markdown]
# <a href="https://colab.research.google.com/github/hibazehramshahzad-lgtm/supervised-machine-learning-model/blob/main/Module_2_statistics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data = pd.read_csv("/content/ecommerce_sales_data.csv")
data
data.head()
data.tail()
# Out:
#      Year    Month         Category Region  Units_Sold   Revenue    Profit  \
# 995  2023  January          Fashion   West          38   5606.14   1577.25
# 996  2024  October        Groceries   East         422  13513.47   2667.70
# 997  2021  January      Electronics  North          85  14304.92   2047.38
# 998  2024      May        Groceries  South         434  66941.72  14621.33
# 999  2021  October  Beauty Products  North         211  19643.44   2722.46
#
#      Customer_Rating  Ad_Spend
# 995              3.2   4788.84
# 996              3.1    495.29
# 997              2.1    370.55
# 998              2.5   2944.75
# 999              1.5    218.01

# %%
sample_data = data.sample(n=100)
sample_data
# Out:
#      Year      Month     Category Region  Units_Sold   Revenue    Profit  \
# 31   2024   December    Groceries   East         260   8203.08   2323.19
# 332  2021    January    Groceries  South         310  49009.75   8377.82
# 244  2024     August   Home Decor  North         483  20839.53   3690.84
# 979  2024    January      Fashion  South         296  12070.02   3259.79
# 218  2020       July  Electronics  North          89   6086.62   1360.61
# ..    ...        ...          ...    ...         ...       ...       ...
# 888  2021  September   Home Decor   West         275  17423.44   2898.70
# 299  2023    October  Electronics  South         408  48654.18  13247.05
# 703  2022   November        Books   West         356  47341.09  12978.78
# 655  2020    October      Fashion  South         467  51639.41   6624.28
# 304  2020   February   Home Decor  North         145   7289.84   1497.54
#
#      Customer_Rating  Ad_Spend
# 31               3.3   1784.33
# ...

# %%
data['Profit'].mean()
# Out:
# np.float64(5494.732660000001)

# %%
data['Profit'].median()
# Out:
# 3820.585

# %%
data['Profit'].mode()
# Out:
# 0    1202.31
# Name: Profit, dtype: float64

# %%
data['Category'].mode()
# Out:
# 0    Electronics
# Name: Category, dtype: object

# %%
data['Ad_Spend'].min()
# Out:
# 101.94

# %%
data['Ad_Spend'].max()
# Out:
# 4997.66

# %%
data['Ad_Spend'].std()
# Out:
# 1408.6621253743256

# %%
data['Revenue'].skew()
data['Revenue'].hist()
plt.show()

# %%
data['Customer_Rating'].skew()
data['Customer_Rating'].hist()
plt.show()

# %%
data['Units_Sold'].skew()
data['Units_Sold'].hist()
plt.show()

# %%
data['Ad_Spend'].skew()
data['Ad_Spend'].hist()
plt.show()

# %%
data['Category'].value_counts(normalize=True)
# Out:
# Category
# Electronics        0.178
# Home Decor         0.172
# Beauty Products    0.168
# Fashion            0.167
# Groceries          0.159
# Books              0.156
# Name: proportion, dtype: float64

# %%
data['Region'].value_counts(normalize=True)
# Out:
# Region
# North    0.269
# South    0.256
# East     0.248
# West     0.227
# Name: proportion, dtype: float64

# %%
data['Revenue'].hist()
plt.xlabel('Revenue')
plt.ylabel('Order Count')
plt.title('Revenue Distribution')
plt.show()

# %%
data[['Ad_Spend','Revenue']].cov()
# Out:
#               Ad_Spend       Revenue
# Ad_Spend  1.984329e+06  4.974229e+05
# Revenue   4.974229e+05  4.955526e+08

# %%
data[['Ad_Spend','Revenue']].corr()
# Out:
#           Ad_Spend   Revenue
# Ad_Spend  1.000000  0.015863
# Revenue   0.015863  1.000000

# %%
data["Revenue"].hist()
plt.title("Original Revenue Distribution")
plt.show()

# %%
sample_data = []

for i in range(1000):
  sample = data["Revenue"].sample(30)
  sample_data.append(sample.mean())

plt.hist(sample_data)
# Out:
# (array([ 17.,  74., 168., 215., 243., 158.,  81.,  32.,   6.,   6.]),
#  array([16865.78566667, 19331.79533333, 21797.805     , 24263.81466667,
#         26729.82433333, 29195.834     , 31661.84366667, 34127.85333333,
#         36593.863     , 39059.87266667, 41525.88233333]),
#  <BarContainer object of 10 artists>)

# %%
from scipy import stats

sample_data = data['Revenue'].sample(100)
t_stats, p_value = stats.ttest_1samp(sample, 500)
print("P_Value = ", p_value)
# Out:
# P_Value =  1.196205642622341e-07

# %%
from scipy.stats import chi2_contingency

sample_data = pd.crosstab(data['Category'], data['Region'])

chi2, p_value , dof, expand = chi2_contingency(sample_data)
print("P_Value = ", p_value)
sample_data
# Out:
# P_Value =  0.8374374776562343
# Region           East  North  South  West
# Category
# Beauty Products    46     45     42    35
# Books              37     43     38    38
# Electronics        41     48     40    49
# Fashion            40     40     43    44
# Groceries          40     42     47    30
# Home Decor         44     51     46    31
