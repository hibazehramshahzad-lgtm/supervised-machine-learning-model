# %% [markdown]
# <a href="https://colab.research.google.com/github/hibazehramshahzad-lgtm/supervised-machine-learning-model/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

from sklearn.metrics import silhouette_score

# %%
df = pd.read_csv("/content/store_customers.csv")
df
# Out:
#      CustomerID Gender   Age  Annual Income (k$)  Spending Score (1-100)
# 0          1000      M  39.0                59.9                    58.0
# 1          1001      M  34.0                48.4                    37.0
# 2          1002      F  40.0                70.5                    26.0
# 3          1003      F  47.0                81.1                    30.0
# 4          1004      F  33.0                42.1                    58.0
# ..          ...    ...   ...                 ...                     ...
# 995        1995      M  80.0               133.3                     1.0
# 996        1996      M  44.0                82.6                    40.0
# 997        1997      F  46.0                67.7                    26.0
# 998        1998      F  28.0                45.7                    59.0
# 999        1999      M  67.0               107.8                     1.0
#
# [1000 rows x 5 columns]

# %%
df.shape
# Out:
# (1000, 5)

# %%
df.columns
# Out:
# Index(['CustomerID', 'Gender', 'Age', 'Annual Income (k$)',
#        'Spending Score (1-100)'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              1000 non-null   int64
#  1   Gender                  997 non-null    object
#  2   Age                     994 non-null    float64
#  3   Annual Income (k$)      996 non-null    float64
#  4   Spending Score (1-100)  994 non-null    float64
# dtypes: float64(3), int64(1), object(1)
# memory usage: 39.2+ KB

# %%
df.describe()
# Out:
#         CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  1000.000000  994.000000          996.000000              994.000000
# mean   1499.500000   38.935614           57.149096               42.645875
# std     288.819436   13.399880           28.628506               20.101589
# min    1000.000000   18.000000           15.000000                1.000000
# 25%    1249.750000   30.000000           34.975000               31.000000
# 50%    1499.500000   36.000000           49.000000               47.000000
# 75%    1749.250000   44.000000           79.400000               57.000000
# max    1999.000000   80.000000          144.100000               92.000000

# %%
df.isnull().sum()
# Out:
# CustomerID                0
# Gender                    3
# Age                       6
# Annual Income (k$)        4
# Spending Score (1-100)    6
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
fill_missing_values = ["Gender","Age","Annual Income (k$)","Spending Score (1-100)"]
for col in fill_missing_values:
  df[col] = df[col].fillna(df[col].mode()[0])

# %%
df.isnull().sum()
# Out:
# CustomerID                0
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
plt.figure(figsize=(15,5))

plt.subplot(1,3,1)
sns.histplot(df['Age'], kde=True)

plt.subplot(1,3,2)
sns.histplot(df['Annual Income (k$)'], kde=True)

plt.subplot(1,3,3)
sns.histplot(df['Spending Score (1-100)'], kde=True)

plt.subplot(1,3,3)
sns.histplot(df['Gender'], kde=True)

plt.show()

# %%
sns.countplot(x='Annual Income (k$)', data=df)

plt.title("Annual Income Distribution")

plt.show()

# %%
plt.figure(figsize=(8,5))

numeric_df = df[['Age', 'Annual Income (k$)', 'Spending Score (1-100)']]
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm')

plt.title("Correlation Heatmap")

plt.show()

# %%
plt.figure(figsize=(10,4))

sns.boxplot(df['Annual Income (k$)'])

plt.show()

# %%
df = df[['Age','Gender', 'Annual Income (k$)', 'Spending Score (1-100)']]

df.head()
# Out:
#     Age Gender  Annual Income (k$)  Spending Score (1-100)
# 0  39.0      M                59.9                    58.0
# 1  34.0      M                48.4                    37.0
# 2  40.0      F                70.5                    26.0
# 3  47.0      F                81.1                    30.0
# 4  33.0      F                42.1                    58.0

# %%
scaler = StandardScaler()

df_numeric = df.drop(columns=['Gender'])
X_scaled = scaler.fit_transform(df_numeric)

# %%
X_scaled[:5]
# Out:
# array([[ 0.0061401 ,  0.1017939 ,  0.76913746],
#        [-0.36825649, -0.29917538, -0.26597448],
#        [ 0.08101942,  0.47138297, -0.80817597],
#        [ 0.60517466,  0.84097204, -0.61101179],
#        [-0.44313581, -0.51883681,  0.76913746]])

# %%
wcss = []

X_scaled_for_kmeans = np.delete(X_scaled, 1, axis=1)

for i in range(1,11):

    km = KMeans(
        n_clusters=i,
        random_state=42
    )

    km.fit(X_scaled_for_kmeans)

    wcss.append(km.inertia_)

# %%
plt.figure(figsize=(8,5))

plt.plot(range(1,11), wcss, marker='o')

plt.xlabel("Number of Clusters")

plt.ylabel("WCSS")

plt.title("Elbow Method")

plt.show()

# %%
km = KMeans(
    n_clusters=3,
    random_state=42
)

# %%
y_means = km.fit_predict(X_scaled_for_kmeans)

# %%
df['Cluster'] = y_means

# %%
df.head()
# Out:
#     Age Gender  Annual Income (k$)  Spending Score (1-100)  Cluster
# 0  39.0      M                59.9                    58.0        1
# 1  34.0      M                48.4                    37.0        0
# 2  40.0      F                70.5                    26.0        0
# 3  47.0      F                81.1                    30.0        0
# 4  33.0      F                42.1                    58.0        1

# %%
cluster_profile = df.drop(columns=['Gender']).groupby('Cluster').mean()

cluster_profile
# Out:
#                Age  Annual Income (k$)  Spending Score (1-100)
# Cluster
# 0        42.070064           71.095860               33.031847
# 1        30.527174           37.055254               56.798913
# 2        66.097015          105.984328                5.007463

# %%
plt.figure(figsize=(10,6))

sns.scatterplot(
    x=df['Annual Income (k$)'],
    y=df['Spending Score (1-100)'],
    hue=df['Cluster'],
    palette='deep',
    s=100
)

plt.title("Customer Segments")

plt.show()

# %%
from sklearn.metrics import silhouette_score

score = silhouette_score(X_scaled_for_kmeans, y_means)

print("Silhouette Score:", score)
# Out:
# Silhouette Score: 0.47423232244971814

# %%
for k in range(2,11):

    km = KMeans(
        n_clusters=k,
        random_state=42
    )

    labels = km.fit_predict(X_scaled)

    score = silhouette_score(X_scaled, labels)

    print(f"K={k}, Score={score}")
# Out:
# K=2, Score=0.5658064855807943
# K=3, Score=0.4764525399951779
# K=4, Score=0.37500193557031136
# K=5, Score=0.34101521303268606
# K=6, Score=0.3294450320849911
# K=7, Score=0.3059052788957357
# K=8, Score=0.32296086148592323
# K=9, Score=0.31656993173212317
# K=10, Score=0.3110914801543452
